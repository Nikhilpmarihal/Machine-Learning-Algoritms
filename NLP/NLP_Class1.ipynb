# %%
sentence = "This is the first classs"
sentence= sentence.lower()
print(sentence)
# Out:
# this is the first classs

# %%
import re
input_str = 'Box A contains 3 Red abd 5 white Balls , While Box B contains 4 red and 2 blue balls'
result = re.sub(r'\d+', '', input_str)
print(result)
# Out:
# Box A contains  Red abd  white Balls , While Box B contains  red and  blue balls
