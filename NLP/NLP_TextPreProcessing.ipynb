# %%
import pandas as pd

# %%
df = pd.read_csv('IMDB Dataset.csv', engine='python', nrows=5)

# %%
df
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ***LOWER CASING***

# %%
df['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
df['review'][3].lower()
# Out:
# "basically there's a family where a little boy (jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie.<br /><br />ok, first of all when you're going to make a film you must decide if its a thriller or a drama! as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film! i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake: just ignore them."

# %%
df['review'].str.lower()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production. <br /><br />the...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically there's a family where a little boy ...
# 4    petter mattei's "love in the time of money" is...
# Name: review, dtype: object

# %% [markdown]
# ***HTML TAGS***

# %%
import re
def remove_html_tags(text):
  pattern = re.compile('<.*?>')
  return pattern.sub(r'', text)

# %%
text = '<html><body><p>Movie: 1</p><p>Actor -- Aamir Khan</p><p>Click here to <a href="http://google.com">download</a></p></body></html>'

# %%
remove_html_tags(text)
# Out:
# 'Movie: 1Actor -- Aamir KhanClick here to download'

# %%
df['review'] = df['review'].apply(remove_html_tags)

# %%
df['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %% [markdown]
# ***REMOVE URL***

# %%
def remove_url(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'',text)

# %%
text1 = 'Check out my project https://github.com/octocat/Hello-World'
text2 = 'Visit my portfolio http://example.com/portfolio'
text3 = 'Learn data science here https://www.coursera.org'
text4 = 'For tutorials click https://www.w3schools.com and explore more'
text5 = 'Read the documentation at https://docs.python.org and practice'
text6 = 'Watch courses on https://www.udemy.com for skill upgrade'
text7 = 'Search insights using https://www.bing.com for references'
text8 = 'Follow updates at https://medium.com to read tech blogs'

# %%
remove_url(text4)
# Out:
# 'For tutorials click  and explore more'

# %% [markdown]
# ***REMOVE PUNCTUATION***

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation

# %%
def remove_punc(text):
  for char in exclude:
    text = text.replace(char,'')
  return text

# %%
text = 'String.With.Punctuation?'

# %%
start = time.time()
print(remove_punc(text))
time1 = time.time() - start
print(time1)
# Out:
# StringWithPunctuation
# 0.00018835067749023438

# %%
def remove_punc1(text):
  return text.translate(str.maketrans('','',exclude))

# %%
start = time.time()
remove_punc1(text)
time2 = time.time() - start
print(time2*50000)
# Out:
# 4.565715789794922

# %%
#FOR THE DATASET
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
stopwords.words('spanish')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
# ...

# %%
def remove_stopwords(text):
  new_text = []
  for word in text.split():
    if word in stopwords.words('english'):
      new_text.append('')
    else:
      new_text.append(word)
  x = new_text[:]
  new_text.clear()
  return " ".join(x)

# %%
df['review'].apply(remove_stopwords)
# Out:
# 0    One    reviewers  mentioned   watching  1 Oz e...
# 1    A wonderful little production. The filming tec...
# 2    I thought    wonderful way  spend time    hot ...
# 3    Basically there's  family   little boy (Jake) ...
# 4    Petter Mattei's "Love   Time  Money"   visuall...
# Name: review, dtype: object

# %% [markdown]
# ***EMOJI HANDLING***

# %%
import re

def remove_emoji(text):
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags
        u"\U00002700-\U000027BF"  # dingbats
        u"\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# %%
remove_emoji("Loved the movie. It was 😘😘")
# Out:
# 'Loved the movie. It was '

# %%
# !pip install emoji

# %%
import emoji
print(emoji.demojize('Python is 🔥'))
# Out:
# Python is :fire:

# %%
print(emoji.demojize('Loved the movie. It was 😘'))
# Out:
# Loved the movie. It was :face_blowing_a_kiss:

# %% [markdown]
# ***1. USING SPLIT FUNCTION***

# %%
# word tokenization
sent1 = 'I am going to delhi'
sent1.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
# sentence tokenization
sent2 = 'I am going to delhi. I will stay there for 3 days. Let\'s hope the trip to be great'
sent2.split('.')
# Out:
# ['I am going to delhi',
#  ' I will stay there for 3 days',
#  " Let's hope the trip to be great"]

# %%
# Problems with split function
sent3 = 'I am going to delhi!'
sent3.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi!']

# %%
sent4 = 'Where do you think I should go? I have 3 day holiday'
sent4.split('.')
# Out:
# ['Where do you think I should go? I have 3 day holiday']

# %% [markdown]
# ***2 REGUALR EXPRESSION***

# %%
import re
sent3 = 'I am going to delhi!'
tokens = re.findall("[\w']+", sent3)
tokens
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-3190589682.py:3: SyntaxWarning: invalid escape sequence '\w'
#   tokens = re.findall("[\w']+", sent3)
# ['I', 'am', 'going', 'to', 'delhi']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""
sentences = re.compile('[.!?] ').split(text)
sentences
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry',
#  "\nLorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %% [markdown]
# ***3.NLTK***

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
import nltk
nltk.download('punkt_tab') # Download 'punkt_tab' resource specifically
sent1 = 'I am going to delhi!'
word_tokenize(sent1)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['I', 'am', 'going', 'to', 'delhi', '!']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""
sent_tokenize(text)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
sent5 = 'I have Ph.D in A.I'
sent6 = "We're here to help! mail us john.mckinley@examplepetstore.comcom"
sent7 = 'A 5km ride cost $10.50'

word_tokenize(sent5)
# Out:
# ['I', 'have', 'Ph.D', 'in', 'A.I']

# %%
word_tokenize(sent6)
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  '!',
#  'mail',
#  'us',
#  'john.mckinley',
#  '@',
#  'examplepetstore.comcom']

# %%
word_tokenize(sent7)
# Out:
# ['A', '5km', 'ride', 'cost', '$', '10.50']

# %% [markdown]
# ***4.Spacy***

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(sent5)
doc2 = nlp(sent6)
doc3 = nlp(sent7)
doc4 = nlp(sent1)

# %%
for token in doc1:
  print(token)
# Out:
# I
# have
# Ph
# .
# D
# in
# A.I

# %% [markdown]
# ***STEMMING***

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
def stem_words(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
sample = "walk walks walking walked"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text = "Probably my all-time focus right now is on improving my skills step by step, learning consistently every day, experimenting with new ideas, fixing past mistakes, building better habits, and pushing myself to grow both personally and professionally without losing momentum"

# %%
print(text)
# Out:
# Probably my all-time focus right now is on improving my skills step by step, learning consistently every day, experimenting with new ideas, fixing past mistakes, building better habits, and pushing myself to grow both personally and professionally without losing momentum

# %%
stem_words(text)
# Out:
# 'probabl my all-tim focu right now is on improv my skill step by step, learn consist everi day, experi with new ideas, fix past mistakes, build better habits, and push myself to grow both person and profession without lose momentum'

# %% [markdown]
# ***LEMMATIZATION***

# %%
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()

sentence = 'He was running  and eating at the same time. He has bad habit os swimming after plaing long hours in the Sun.'
punctuations = "?:!.,;"
sentence_words = nltk.word_tokenize(sentence)
for word in sentence_words:
  if word in punctuations:
    sentence_words.remove(word)
sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
  print("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word,pos='v')))
# Out:
# Word                Lemma
# He                  He
# was                 be
# running             run
# and                 and
# eating              eat
# at                  at
# the                 the
# same                same
# time                time
# He                  He
# has                 have
# bad                 bad
# habit               habit
# os                  os
# swimming            swim
# after               after
# plaing              plaing
# long                long
# hours               hours
# in                  in
# the                 the
# Sun                 Sun
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
